# %% [markdown]
# # Import the necessary packages

# %%
import pandas as pd
from config import *
from utils import get_all_players_last_stats,create_features
import warnings
import tqdm
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("datasets/previous_seasons.csv", index_col=0)
data.head()
# Out:
#                             name position         team   xP  assists  bonus  \
# 0                    Eric Bailly      DEF      Man Utd  0.0        0      0
# 1                   Keinan Davis      FWD  Aston Villa  0.4        0      0
# 2         Ayotomiwa Dele-Bashiru      MID      Watford  0.0        0      0
# 3              James Ward-Prowse      MID  Southampton  2.3        0      0
# 4  Bruno Miguel Borges Fernandes      MID      Man Utd  4.4        0      3
#
#    bps  clean_sheets  creativity  element  ...  element_type_ex   season  GW  \
# 0    0             0         0.0      286  ...              DEF  2021-22   1
# 1    0             0         0.0       49  ...              FWD  2021-22   1
# 2    0             0         0.0      394  ...              NaN  2021-22   1
# 3   20             0        30.5      341  ...              MID  2021-22   1
# 4   61             0        35.9      277  ...              MID  2021-22   1
#
#       opponent  opponent_last_season_position expected_assists  \
# 0        Leeds                              9              NaN
# 1      Watford                             20              NaN
# 2  Aston Villa                             11              NaN
# 3      Everton                             10              NaN
# 4        Leeds                              9              NaN
#
#    expected_goal_involvements  expected_goals  expected_goals_conceded  starts
# 0                         NaN             NaN                      NaN     NaN
# 1                         NaN             NaN                      NaN     NaN
# 2                         NaN             NaN                      NaN     NaN
# 3                         NaN             NaN                      NaN     NaN
# 4                         NaN             NaN                      NaN     NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# # Dropping the Unused Columns

# %%
data.drop(unused_columns,axis=1,inplace=True)
# "xP","opponent_team","expected_assists","expected_goal_involvements","expected_goals",
# "expected_goals_conceded","element_type_ex","team_h_score","team_a_score","element" , "round" ,"fixture","starts"
data.head()
# Out:
#                             name position         team  assists  bonus  bps  \
# 0                    Eric Bailly      DEF      Man Utd        0      0    0
# 1                   Keinan Davis      FWD  Aston Villa        0      0    0
# 2         Ayotomiwa Dele-Bashiru      MID      Watford        0      0    0
# 3              James Ward-Prowse      MID  Southampton        0      0   20
# 4  Bruno Miguel Borges Fernandes      MID      Man Utd        0      3   61
#
#    clean_sheets  creativity  goals_conceded  goals_scored  ...  ict_index_ex  \
# 0             0         0.0               0             0  ...          21.1
# 1             0         0.0               0             0  ...          31.7
# 2             0         0.0               0             0  ...           NaN
# 3             0        30.5               3             0  ...         226.5
# 4             0        35.9               1             3  ...         396.2
#
#    clean_sheets_ex red_cards_ex  yellow_cards_ex  selected_by_percent_ex  \
# 0              3.0          0.0              3.0                     0.3
# 1              1.0          0.0              0.0                     7.6
# 2              NaN          NaN              NaN                     NaN
# 3              9.0          0.0              5.0                    11.7
# 4             13.0          0.0              6.0                    48.7
#
#    now_cost_ex   season  GW     opponent  opponent_last_season_position
# 0         48.0  2021-22   1        Leeds                              9
# 1         42.0  2021-22   1      Watford                             20
# 2          NaN  2021-22   1  Aston Villa                             11
# 3         59.0  2021-22   1      Everton                             10
# 4        113.0  2021-22   1        Leeds                              9
#
# [5 rows x 52 columns]

# %% [markdown]
# # Adding Kick-off time as a feature

# %%
data["kickoff_time"]=pd.to_datetime(data["kickoff_time"])

# %%
data.sort_values(by="kickoff_time",inplace=True)

# %%
print(data.columns)
print(len(data.columns))
# Out:
# Index(['name', 'position', 'team', 'assists', 'bonus', 'bps', 'clean_sheets',
#        'creativity', 'goals_conceded', 'goals_scored', 'ict_index',
#        'influence', 'kickoff_time', 'minutes', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'saves', 'selected', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'yellow_cards', 'last_season_position',
#        'percent_value', 'position rank', 'match_result', 'goals_scored_ex',
#        'assists_ex', 'total_points_ex', 'minutes_ex', 'goals_conceded_ex',
#        'creativity_ex', 'influence_ex', 'threat_ex', 'bonus_ex', 'bps_ex',
#        'ict_index_ex', 'clean_sheets_ex', 'red_cards_ex', 'yellow_cards_ex',
#        'selected_by_percent_ex', 'now_cost_ex', 'season', 'GW', 'opponent',
#        'opponent_last_season_position'],
#       dtype='object')
# 52

# %% [markdown]
# # Adding Previous stats to players

# %%
for stat in (history_stats):
    print(stat)
    data=get_all_players_last_stats(data,stat)
# Out:
# assists
# bonus
# bps
# clean_sheets
# creativity
# goals_conceded
# goals_scored
# ict_index
# influence
# minutes
# own_goals
# penalties_missed
# penalties_saved
# red_cards
# saves
# selected
# threat
# total_points
# transfers_in
# transfers_out
# value
# match_result

# %% [markdown]
# # Feature Engineering
# -Mean
# -Standard Deviation

# %%
data=create_features(data,mean_features,std_features)
data.drop([f"last {no_last_stats} {stat}" for stat in history_stats],axis=1,inplace=True)

data.to_csv("cleaned_dataset/cleaned_previous_seasons.csv")
# Out:
# assists
# bonus
# bps
# clean_sheets
# creativity
# goals_conceded
# goals_scored
# ict_index
# influence
# minutes
# own_goals
# penalties_missed
# penalties_saved
# red_cards
# saves
# selected
# threat
# total_points
# transfers_in
# transfers_out
# value
# match_result
# bps
# creativity
# ict_index
# influence
# minutes
# selected
# threat
# total_points
# transfers_in
# transfers_out
# value
